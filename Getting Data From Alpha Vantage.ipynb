# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %%
ALPHA_VANTAGE_API_KEY = "6EHD1DU362A2G6JV"
crypto_api = CryptoCurrencies(key=ALPHA_VANTAGE_API_KEY, output_format='pandas')

# %%
data, meta_data = crypto_api.get_digital_currency_daily(symbol="BTC", market="EUR")

# %%
meta_data
# Out:
# {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#  '2. Digital Currency Code': 'BTC',
#  '3. Digital Currency Name': 'Bitcoin',
#  '4. Market Code': 'EUR',
#  '5. Market Name': 'Euro',
#  '6. Last Refreshed': '2022-10-07 00:00:00',
#  '7. Time Zone': 'UTC'}

# %%
data.head(30)
# Out:
#             1a. open (EUR)  1b. open (USD)  ...     5. volume  6. market cap (USD)
# date                                        ...
# 2022-10-07    20373.855869        19960.67  ...    5473.02045           5473.02045
# 2022-10-06    20575.535982        20158.26  ...  320122.17020         320122.17020
# 2022-10-05    20758.812874        20337.82  ...  312239.75224         312239.75224
# 2022-10-04    20035.401956        19629.08  ...  327012.00127         327012.00127
# 2022-10-03    19452.235218        19057.74  ...  293585.75212         293585.75212
# 2022-10-02    19712.003368        19312.24  ...  206812.47032         206812.47032
# 2022-10-01    19824.658027        19422.61  ...  165625.13959         165625.13959
# 2022-09-30    19996.064178        19590.54  ...  444322.95340         444322.95340
# 2022-09-29    19814.665374        19412.82  ...  406424.93256         406424.93256
# 2022-09-28    19473.016670        19078.10  ...  521385.45547         521385.45547
# ...

# %%
crypto_api.get_digital_currency_exchange_rate(from_currency="BTC", to_currency="USD")[0].transpose()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 crypto_api.get_digital_currency_exchange_rate(from_currency="BTC", to_currency="USD")[0].transpose()
#
# File ~/anaconda3/lib/python3.9/site-packages/alpha_vantage/alphavantage.py:218, in AlphaVantage._output_format.<locals>._format_wrapper(self, *args, **kwargs)
#     216 @wraps(func)
#     217 def _format_wrapper(self, *args, **kwargs):
# --> 218     call_response, data_key, meta_data_key = func(
#     219         self, *args, **kwargs)
#     220     if 'json' in self.output_format.lower() or 'pandas' \
#     221             in self.output_format.lower():
#     222         if data_key is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/alpha_vantage/alphavantage.py:160, in AlphaVantage._call_api_on_func.<locals>._call_wrapper(self, *args, **kwargs)
#     158 else:
# ...
